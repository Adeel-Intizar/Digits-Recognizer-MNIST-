# %%
# %tensorflow_version 2.x
from tensorflow.keras.datasets import mnist
from tensorflow import keras
import tensorflow as tf

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
train_images = train_images.reshape(train_images.shape[0],784)
test_images = test_images.reshape(test_images.shape[0], 784)

# %%
model = keras.Sequential([
                          keras.layers.Dense(2000, activation='relu', kernel_initializer='he_uniform', input_dim = 784),
                          keras.layers.Dropout(0.4),
                          keras.layers.Dense(1000, activation='relu', kernel_initializer='he_uniform'),
                          keras.layers.Dropout(0.4),
                          keras.layers.Dense(500, activation='relu', kernel_initializer='he_uniform'),
                          keras.layers.Dropout(0.4),
                          keras.layers.Dense(100, activation='relu', kernel_initializer='he_uniform'),
                          keras.layers.Dropout(0.4),
                          keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 2000)              1570000
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2000)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1000)              2001000
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 500)               500500
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               50100
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 4,122,610
# Trainable params: 4,122,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
model.fit(train_images, train_labels, epochs=150, batch_size=256)
# Out:
# Train on 60000 samples
# Epoch 1/150
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.2039 - acc: 0.9444
# Epoch 2/150
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.1450 - acc: 0.9611
# Epoch 3/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.1157 - acc: 0.9689
# Epoch 4/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.1010 - acc: 0.9727
# Epoch 5/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0850 - acc: 0.9766
# Epoch 6/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0742 - acc: 0.9793
# Epoch 7/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0674 - acc: 0.9804
# Epoch 8/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0631 - acc: 0.9819
# Epoch 9/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0563 - acc: 0.9836
# Epoch 10/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0528 - acc: 0.9846
# Epoch 11/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0540 - acc: 0.9845
# Epoch 12/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0514 - acc: 0.9855
# Epoch 13/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0458 - acc: 0.9866
# Epoch 14/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0434 - acc: 0.9876
# Epoch 15/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0407 - acc: 0.9877
# Epoch 16/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0363 - acc: 0.9889
# Epoch 17/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0361 - acc: 0.9898
# Epoch 18/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0328 - acc: 0.9905
# Epoch 19/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0352 - acc: 0.9894
# Epoch 20/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0318 - acc: 0.9905
# Epoch 21/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0332 - acc: 0.9908
# Epoch 22/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0319 - acc: 0.9905
# Epoch 23/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0302 - acc: 0.9912
# Epoch 24/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0339 - acc: 0.9901
# Epoch 25/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0314 - acc: 0.9912
# Epoch 26/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0318 - acc: 0.9911
# Epoch 27/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0286 - acc: 0.9918
# Epoch 28/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0280 - acc: 0.9920
# Epoch 29/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0223 - acc: 0.9939
# Epoch 30/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0256 - acc: 0.9926
# Epoch 31/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0243 - acc: 0.9930
# Epoch 32/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0248 - acc: 0.9931
# Epoch 33/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0207 - acc: 0.9942
# Epoch 34/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0234 - acc: 0.9939
# Epoch 35/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0231 - acc: 0.9936
# Epoch 36/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0238 - acc: 0.9931
# Epoch 37/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0213 - acc: 0.9944
# Epoch 38/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0219 - acc: 0.9941
# Epoch 39/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0236 - acc: 0.9939
# Epoch 40/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0179 - acc: 0.9951
# Epoch 41/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0194 - acc: 0.9944
# Epoch 42/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.
150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0102 - acc: 0.9977
# Epoch 112/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.0118 - acc: 0.9976
# Epoch 113/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0084 - acc: 0.9977
# Epoch 114/150
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.0115 - acc: 0.9976
# Epoch 115/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0113 - acc: 0.9977
# Epoch 116/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0103 - acc: 0.9975
# Epoch 117/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0106 - acc: 0.9976
# Epoch 118/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0100 - acc: 0.9976
# Epoch 119/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0082 - acc: 0.9977
# Epoch 120/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0120 - acc: 0.9975
# Epoch 121/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0123 - acc: 0.9974
# Epoch 122/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0169 - acc: 0.9965
# Epoch 123/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0118 - acc: 0.9974
# Epoch 124/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0111 - acc: 0.9975
# Epoch 125/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0097 - acc: 0.9979
# Epoch 126/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0073 - acc: 0.9982
# Epoch 127/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0089 - acc: 0.9980
# Epoch 128/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0091 - acc: 0.9980
# Epoch 129/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0139 - acc: 0.9973
# Epoch 130/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0144 - acc: 0.9968
# Epoch 131/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0112 - acc: 0.9977
# Epoch 132/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0100 - acc: 0.9979
# Epoch 133/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0139 - acc: 0.9976
# Epoch 134/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0101 - acc: 0.9977
# Epoch 135/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0125 - acc: 0.9973
# Epoch 136/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0082 - acc: 0.9979
# Epoch 137/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0096 - acc: 0.9979
# Epoch 138/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0070 - acc: 0.9984
# Epoch 139/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0088 - acc: 0.9980
# Epoch 140/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0101 - acc: 0.9977
# Epoch 141/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0085 - acc: 0.9978
# Epoch 142/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0096 - acc: 0.9980
# Epoch 143/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0122 - acc: 0.9974
# Epoch 144/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0157 - acc: 0.9971
# Epoch 145/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0099 - acc: 0.9976
# Epoch 146/150
# 60000/60000 [==============================] - 2s 37us/sample - loss: 0.0115 - acc: 0.9973
# Epoch 147/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0094 - acc: 0.9979
# Epoch 148/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0113 - acc: 0.9976
# Epoch 149/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0106 - acc: 0.9972
# Epoch 150/150
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.0113 - acc: 0.9975

# %%
loss, acc = model.evaluate(train_images, train_labels, verbose=0)
print('Training Loss: {:.4} /t Training Accuracy {:.4}'.format(loss, acc))
loss, acc = model.evaluate(test_images, test_labels, verbose=0)
print('Testing Loss: {:.4} /t Testing Accuracy {:.4}'.format(loss, acc))
# Out:
# Training Loss: 0.0001306 /t Training Accuracy 1.0
# Testing Loss: 0.1809 /t Testing Accuracy 0.9881

# %%
json_model = model.to_json()
with open('model.json', 'w') as json_file:
  json_file.write(json_model)

# %%
yaml_model = model.to_yaml()
with open('model.yaml', 'w') as yaml_file:
  yaml_file.write(yaml_model)

# %%
model.save('Model_1.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model  = load_model('CNN_Model.h5')

# %%
test_images = test_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 130us/sample - loss: 0.0716 - acc: 0.9925
# [0.0716219940434482, 0.9925]

# %%
json_model = model.to_json()
with open('cnn_model.json', 'w') as json_file:
  json_file.write(json_model)

yaml_model = model.to_yaml()
with open('cnn_model.yaml', 'w') as yaml_file:
  yaml_file.write(yaml_model)
